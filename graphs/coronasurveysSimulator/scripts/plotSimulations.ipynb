# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import datetime as dt
import numpy as np
sns.set(style="darkgrid")

# %%
dfRingModel=pd.read_csv('ringmodel-out-100k.result',delim_whitespace=True, header=None)


dsx=sns.lineplot(data=dfRingModel, x=1, y=6, sort=False)
sns.lineplot(data=dfRingModel, ax=dsx, x=1, y=10, sort=False)

# %%
dfDBLP=pd.read_csv('com-dblp.ungraph.results',delim_whitespace=True, header=None)
dsx=sns.lineplot(data=dfDBLP, x=1, y=6,legend='full')
sns.lineplot(data=dfDBLP, ax=dsx, x=1, y=10)

# %%
dsx=sns.lineplot(data=dfDBLP, x=1, y=5)
sns.lineplot(data=dfDBLP, ax=dsx, x=1, y=9)

# %%
dfDBLPe01=pd.read_csv('com-dblp.ungraph-e01.results',delim_whitespace=True, header=None)
dsx=sns.lineplot(data=dfDBLPe01, x=1, y=6)
sns.lineplot(data=dfDBLPe01, ax=dsx, x=1, y=10)

# %%
dsx=sns.lineplot(data=dfDBLPe01, x=1, y=5)
sns.lineplot(data=dfDBLPe01, ax=dsx, x=1, y=9)

# %%
dfFBe01=pd.read_csv('facebook_combined-r10.results',delim_whitespace=True, header=None)
dsx=sns.lineplot(data=dfFBe01, x=1, y=6)
sns.lineplot(data=dfFBe01, ax=dsx, x=1, y=10)

# %%
dsx=sns.lineplot(data=dfFBe01, x=1, y=5)
sns.lineplot(data=dfFBe01, ax=dsx, x=1, y=9)

# %%
dfFBe01f5=pd.read_csv('facebook_combined-e0.01-r100-f.5.results',delim_whitespace=True, header=None)
dsx=sns.lineplot(data=dfFBe01f5, x=1, y=6)
sns.lineplot(data=dfFBe01f5, ax=dsx, x=1, y=10)

# %%
dsx=sns.lineplot(data=dfFBe01f5, x=1, y=5)
sns.lineplot(data=dfFBe01f5, ax=dsx, x=1, y=9)
